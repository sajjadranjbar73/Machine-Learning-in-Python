# %%
import pickle
model = pickle.load(open('catboost_regression.7learn', 'rb'))

# %%
model

# %%
import pandas as pd
data_test = pd.read_csv('test.csv')
data_test.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont5     cont6  \
# 0   4    A    B    A    A    A    A    A    A    B  ...  0.281143  0.466591
# 1   6    A    B    A    B    A    A    A    A    B  ...  0.836443  0.482425
# 2   9    A    B    A    B    B    A    B    A    B  ...  0.718531  0.212308
# 3  12    A    A    A    A    B    A    A    A    A  ...  0.397069  0.369930
# 4  15    B    A    A    A    A    B    A    A    A  ...  0.302678  0.398862
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13    cont14
# 0  0.317681  0.61229  0.34365  0.38016  0.377724  0.369858  0.704052  0.392562
# 1  0.443760  0.71330  0.51890  0.60401  0.689039  0.675759  0.453468  0.208045
# 2  0.325779  0.29758  0.34365  0.30529  0.245410  0.241676  0.258586  0.297232
# 3  0.342355  0.40028  0.33237  0.31480  0.348867  0.341872  0.592264  0.555955
# 4  0.391833  0.23688  0.43731  0.50556  0.359572  0.352251  0.301535  0.825823
#
# [5 rows x 131 columns]

# %%
data_test.drop(['id'], axis=1, inplace=True)

# %%
model.predict(data_test)
# Out:
# array([7.38585801, 7.58560717, 9.10137388, ..., 7.85818788, 6.77654049,
#        8.23628274])

# %%
import numpy as np

# %%
np.exp(model.predict(data_test))
# Out:
# array([1613.01117861, 1969.64217718, 8967.60466594, ..., 2586.82848471,
#         877.029374  , 3775.47976374])

# %%
data_test = pd.read_csv('test.csv')
X = data_test.drop(['id'], axis=1)
data_test['loss'] = np.exp(model.predict(X))

# %%
data_test.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   4    A    B    A    A    A    A    A    A    B  ...  0.466591  0.317681
# 1   6    A    B    A    B    A    A    A    A    B  ...  0.482425  0.443760
# 2   9    A    B    A    B    B    A    B    A    B  ...  0.212308  0.325779
# 3  12    A    A    A    A    B    A    A    A    A  ...  0.369930  0.342355
# 4  15    B    A    A    A    A    B    A    A    A  ...  0.398862  0.391833
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14  \
# 0  0.61229  0.34365  0.38016  0.377724  0.369858  0.704052  0.392562
# 1  0.71330  0.51890  0.60401  0.689039  0.675759  0.453468  0.208045
# 2  0.29758  0.34365  0.30529  0.245410  0.241676  0.258586  0.297232
# 3  0.40028  0.33237  0.31480  0.348867  0.341872  0.592264  0.555955
# 4  0.23688  0.43731  0.50556  0.359572  0.352251  0.301535  0.825823
#
#           loss
# 0  1613.011179
# 1  1969.642177
# 2  8967.604666
# 3  4972.007980
# ...

# %%
data_test.to_excel('prediction001.xlsx')
