# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].hist()

# %%
data['Age'].hist(bins=40)

# %%
data['SibSp'].hist(bins=8)

# %%
data['Pclass'].hist(bins=20)

# %%
data['Survived'].hist(bins=2)

# %%
sns.set_style('darkgrid')

# %%
data['Survived'].hist(bins=2)

# %%
data['Survived'].plot(kind='hist', bins=2)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Pclass', figsize=(10, 8))

# %%
data.sort_values(['Age']).plot.line(x='Age', y='Fare', figsize=(10, 8))

# %%
data.sort_values(['Embarked']).plot.line(x='Embarked', y='Fare', figsize=(10, 8))

# %%
data.plot.scatter(x='Age', y='Pclass', figsize=(10, 8))

# %%
data.plot.scatter(x='Age', y='Fare', figsize=(10, 8))

# %%
data.plot.hexbin(x='Age', y='Fare', gridsize=10, figsize=(10, 8))

# %%
data.plot.hexbin(x='Age', y='Pclass', gridsize=10, figsize=(10, 8))

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].plot.kde()

# %%
data['Fare'].plot.kde()

# %%
data.hist(figsize=(10, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb201940910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe596b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe56a950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe52b190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe4dc990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe49e1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe44f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe411210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1fe3c5a50>]],
#       dtype=object)

# %%
data.drop(['PassengerId', 'Fare', 'Age'], axis=1).plot.box(figsize=(12, 8))

# %%
pd.DataFrame([1, 2, 3, 7, 9, 10, 10.3, 20]).quantile([0.25, 0.5, 0.75])

21.1
# Out:
#            0
# 0.25   2.750
# 0.50   8.000
# 0.75  10.075

# %%
pd.DataFrame([1, 2, 3, 7, 9, 10, 10.3, 22]).plot.box()
